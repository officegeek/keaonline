# %% [markdown]
# #

# %%
# Importing libraries 
import pandas as pd
import numpy as np

# %%
# Loading dataset labeled "Telecom Customer Churn" 
# Link: https://www.mavenanalytics.io/data-playground
df = pd.read_csv("telecom_customer_churn.csv")

# %%
print(df.shape)
print(df.info())
# Out:
# (7043, 38)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
# Columns with NaN (null) values.
df.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
df[df['Multiple Lines'].isnull()].head(3)

# When Internet Service = No then the Internet columns have NaN because it's not available.
# Out:
#    Customer ID  Gender  Age Married  Number of Dependents  \
# 10  0017-DINOC    Male   47      No                     0
# 14  0019-GFNTW  Female   39      No                     0
# 16  0020-JDNXP  Female   52     Yes                     1
#
#                    City  Zip Code   Latitude   Longitude  Number of Referrals  \
# 10      Rancho Santa Fe     92091  32.993560 -117.207121                    0
# 14           Los Olivos     93441  34.704340 -120.026090                    0
# 16  Point Reyes Station     94956  38.060264 -122.830646                    0
#
#     ...   Payment Method Monthly Charge Total Charges  Total Refunds  \
# 10  ...      Credit Card          45.20       2460.55            0.0
# 14  ...  Bank Withdrawal          45.05       2560.10            0.0
# 16  ...      Credit Card          61.25       1993.20            0.0
#
#    Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# ...

# %%
# Replace binary columns with 1,0

df['Customer Status']=df['Customer Status'].replace(['Stayed','Churned'], [0,1])
df['Married']=df['Married'].replace(['Yes','No'],[1,0])
df['Gender'] = df['Gender'].replace(['Female','Male'],[0,1]) 
df['Paperless Billing']=df['Paperless Billing'].replace(['Yes','No'],[1,0])
df['Internet Service']=df['Internet Service'].replace(['Yes','No'],[1,0])
df['Phone Service']=df['Phone Service'].replace(['Yes','No'],[1,0])

# %%
df.head(2)
# Out:
#   Customer ID  Gender  Age  Married  Number of Dependents          City  \
# 0  0002-ORFBO       0   37        1                     0  Frazier Park
# 1  0003-MKNFE       1   46        0                     0      Glendale
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...  Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...     Credit Card
# 1     91206  34.162515 -118.203869                    0  ...     Credit Card
#
#   Monthly Charge  Total Charges  Total Refunds Total Extra Data Charges  \
# 0           65.6          593.3           0.00                        0
# 1           -4.0          542.4          38.33                       10
#
#    Total Long Distance Charges Total Revenue  Customer Status Churn Category  \
# 0                       381.51        974.81                0            NaN
# 1                        96.21        610.28                0            NaN
#
#   Churn Reason
# 0          NaN
# 1          NaN
#
# ...

# %%
# Fill the columns that are NaN and are numerical columns with 0.
df['Avg Monthly GB Download'] = df['Avg Monthly GB Download'].fillna(0)
df['Avg MonthlyLong Distance Charges'] = df['Avg Monthly Long Distance Charges'].fillna(0)

# %%
# replace all of the columns that are text and have more than 2 unique values with “unknown”.
cols_to_change= ['Churn Category','Churn Reason', 'Unlimited Data','Streaming Music','Streaming Movies','Streaming TV',
'Premium Tech Support','Device Protection Plan','Online Security',
'Online Backup','Internet Type','Multiple Lines']

df[cols_to_change]=df[cols_to_change].fillna('Unknown')
